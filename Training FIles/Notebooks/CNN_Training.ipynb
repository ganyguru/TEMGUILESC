# %%
# !pip install -qq tensorflow[and-cuda]==2.15.0 tf-keras~=2.15.0 tensorrt-libs==8.6.1 --extra-index-url https://pypi.nvidia.com
# !pip install -qq sionna

# %%
from google.colab import drive
drive.mount('/content/drive')#, force_remount=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Mar  5 03:58:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             43W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU Available: ", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.15.0
# GPU Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU memory growth enabled")
# Out:
# GPU memory growth enabled

# %%
import os
import numpy as np
import tensorflow as tf
import cv2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, Lambda

# %%
# Configuration (same as your UNet model)
seed = 42
np.random.seed = seed
IMG_WIDTH = 512
IMG_HEIGHT = 1024
IMG_CHANNELS = 3
nfilters = 1024  # Base filter count from your UNet

# %%
# Define dice coefficient metric
def dice_coefficient(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)
    return numerator / (denominator + tf.keras.backend.epsilon())

def precision_metric(y_true, y_pred):
    # True positives: element-wise multiplication gives non-zero only where both are non-zero
    true_positives = tf.reduce_sum(y_true * y_pred)

    # All predicted positives
    predicted_positives = tf.reduce_sum(y_pred)

    # Return precision with epsilon to avoid division by zero
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())


def hausdorff_distance(y_true, y_pred, max_dist=1500.0):
    """
    Calculate inverse of the Hausdorff distance between binary masks

    Args:
        y_true: Ground truth binary mask
        y_pred: Predicted binary mask
        max_dist: Maximum distance to use for normalization

    Returns:
        Inverse of the Hausdorff distance (1/HD)
    """
    # Convert predictions to binary
    y_pred_binary = tf.cast(tf.greater_equal(y_pred, 0.5), tf.float32)

    # Find coordinates of non-zero values (foreground pixels)
    y_true_positions = tf.where(tf.greater(y_true, 0))
    y_pred_positions = tf.where(tf.greater(y_pred_binary, 0))

    # If either mask is empty, return zero (maximum distance)
    if tf.equal(tf.shape(y_true_positions)[0], 0) or tf.equal(tf.shape(y_pred_positions)[0], 0):
        return tf.constant(0.0, dtype=tf.float32)

    # Compute all pairwise distances between coordinates
    # From each point in y_true to all points in y_pred
    def minimum_distance(point):
        dists = tf.sqrt(tf.reduce_sum(tf.square(tf.cast(point, tf.float32) -
                                              tf.cast(y_pred_positions, tf.float32)), axis=1))
        return tf.reduce_min(dists)

    # Calculate directed Hausdorff distances
    forward_hausdorff = tf.reduce_max(tf.map_fn(minimum_distance, y_true_positions,
                                              fn_output_signature=tf.float32))

    def minimum_distance_reverse(point):
        dists = tf.sqrt(tf.reduce_sum(tf.square(tf.cast(point, tf.float32) -
                                              tf.cast(y_true_positions, tf.float32)), axis=1))
        return tf.reduce_min(dists)

    # Reverse direction (from y_pred to y_true)
    reverse_hausdorff = tf.reduce_max(tf.map_fn(minimum_distance_reverse, y_pred_positions,
                                              fn_output_signature=tf.float32))

    # Hausdorff distance is the maximum of the two directed distances
    hausdorff_dist = tf.maximum(forward_hausdorff, reverse_hausdorff)

    # Return inverse Hausdorff distance (1/HD), avoiding division by zero
    # Clipping the distance to ensure it's not too small
    hausdorff_dist = tf.clip_by_value(hausdorff_dist, 1e-7, max_dist)
    return hausdorff_dist

# %%
# CNN without skip connections
def build_cnn_no_skip(input_shape):
    """Build a CNN with similar architecture to UNet but without skip connections"""
    inputs = Input(input_shape)
    s = Lambda(lambda x: x / 255)(inputs)

    # Encoder path (same as UNet)
    c1 = Conv2D(int(nfilters/8), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(int(nfilters/8), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(int(nfilters/4), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(int(nfilters/4), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(int(nfilters/2), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(int(nfilters/2), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(int(nfilters), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(int(nfilters), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(int(nfilters*2), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(int(nfilters*2), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    # Decoder path (without skip connections)
    u6 = Conv2DTranspose(int(nfilters), (2, 2), strides=(2, 2), padding='same')(c5)
    c6 = Conv2D(int(nfilters), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(int(nfilters), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(int(nfilters/2), (2, 2), strides=(2, 2), padding='same')(c6)
    c7 = Conv2D(int(nfilters/2), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(int(nfilters/2), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(int(nfilters/4), (2, 2), strides=(2, 2), padding='same')(c7)
    c8 = Conv2D(int(nfilters/4), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(int(nfilters/4), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(int(nfilters/8), (2, 2), strides=(2, 2), padding='same')(c8)
    c9 = Conv2D(int(nfilters/8), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(int(nfilters/8), (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                 loss='binary_crossentropy',
                 metrics=[dice_coefficient,precision_metric,hausdorff_distance])

    return model

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.utils import Sequence

class DataGenerator(Sequence):
    """Data generator for loading images in batches during training."""

    def __init__(self, file_list, input_path, label_path, batch_size=8,
                 img_height=1024, img_width=512, img_channels=3, shuffle=True):
        self.file_list = file_list
        self.input_path = input_path
        self.label_path = label_path
        self.batch_size = batch_size
        self.img_height = img_height
        self.img_width = img_width
        self.img_channels = img_channels
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.file_list))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __len__(self):
        """Return the number of batches per epoch"""
        return int(np.ceil(len(self.file_list) / self.batch_size))

    def __getitem__(self, index):
        """Generate one batch of data"""
        # Generate indexes of the batch
        batch_indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

        # Get list of file names for the batch
        batch_files = [self.file_list[i] for i in batch_indexes]

        # Generate data
        X, y = self._data_generation(batch_files)

        return X, y

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        self.indexes = np.arange(len(self.file_list))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def _data_generation(self, batch_files):
        """Generate data containing batch_size samples"""
        # Initialize arrays
        X = np.zeros((len(batch_files), self.img_height, self.img_width, self.img_channels), dtype=np.float32)
        y = np.zeros((len(batch_files), self.img_height, self.img_width, 1), dtype=np.float32)

        # Load and process images
        for i, file in enumerate(batch_files):
            # Load input image and normalize to [0,1] range
            img_path = os.path.join(self.input_path, file)
            img = cv2.imread(img_path)[:,:,:self.img_channels]
            X[i] = img.astype(np.float32) / 255.0

            # Load ground truth image
            gt_path = os.path.join(self.label_path, file)
            gt = cv2.imread(gt_path)[:,:,:1]
            y[i] = (gt > 0).astype(np.float32)

        return X, y

# Setup data loading

# %%
# !cp '/content/drive/MyDrive/TEM_Rebuttal_Files/JoM_rebuttal/Large_Dataset.zip' Datafiles.zip

# %%
import zipfile

with zipfile.ZipFile('Datafiles.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
# Setup data loading
TRAIN_PATH = '/content/Large_Dataset/1024x512/train/'
TRAIN_PATH_Y = '/content/Large_Dataset/1024x512/ground/'
IMG_HEIGHT = 1024
IMG_WIDTH = 512
IMG_CHANNELS = 3
BATCH_SIZE = 8  # Adjust this based on your GPU memory

# Get file list
train_files = [f for f in os.listdir(TRAIN_PATH) if f.endswith('.png')]
print(f"Found {len(train_files)} training images")

# Create validation split
from sklearn.model_selection import train_test_split
train_files, val_files = train_test_split(train_files, test_size=0.1, random_state=42)

# Create data generators
train_generator = DataGenerator(
    train_files,
    TRAIN_PATH,
    TRAIN_PATH_Y,
    batch_size=BATCH_SIZE,
    img_height=IMG_HEIGHT,
    img_width=IMG_WIDTH,
    img_channels=IMG_CHANNELS
)

val_generator = DataGenerator(
    val_files,
    TRAIN_PATH,
    TRAIN_PATH_Y,
    batch_size=BATCH_SIZE,
    img_height=IMG_HEIGHT,
    img_width=IMG_WIDTH,
    img_channels=IMG_CHANNELS,
    shuffle=False
)
# Out:
# Found 1690 training images

# %%
import pandas as pd

# %%
def train_cnn_model(train_generator, val_generator, epochs=100):
    """Train CNN model without skip connections using data generators"""
    input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

    # Build CNN model
    print("Building CNN without skip connections...")
    cnn_no_skip_model = build_cnn_no_skip(input_shape)
    cnn_no_skip_model.summary()

    # Define callbacks
    callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=10, monitor='val_loss', restore_best_weights=True),
        tf.keras.callbacks.TensorBoard(log_dir='logs'),
        tf.keras.callbacks.ModelCheckpoint(
            '1024_512_CNN.hdf5',
            verbose=1,
            save_best_only=True
        )
    ]

    # Train CNN without skip connections using generators
    print("\nTraining CNN without skip connections...")
    cnn_model_history = cnn_no_skip_model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=callbacks
    )

    # Save final model
    cnn_no_skip_model.save('1024_512_CNN.hdf5')
    df_history = pd.DataFrame(cnn_model_history.history)
    df_history.to_csv('model_training_history.csv', index=False)
    print("\nTraining completed. Model weights saved.")
    return cnn_no_skip_model

# Usage:
# Create generators as shown in previous code
train_generator = DataGenerator(train_files, TRAIN_PATH, TRAIN_PATH_Y, batch_size=4)
val_generator = DataGenerator(val_files, TRAIN_PATH, TRAIN_PATH_Y, batch_size=4, shuffle=False)

# %%
# Train the model using generators
cnn_model = train_cnn_model(train_generator, val_generator, epochs=100)
# Out:
# Building CNN without skip connections...
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1024, 512, 3)]    0
#
#  lambda_2 (Lambda)           (None, 1024, 512, 3)      0
#
#  conv2d_38 (Conv2D)          (None, 1024, 512, 128)    3584
#
#  dropout_18 (Dropout)        (None, 1024, 512, 128)    0
#
#  conv2d_39 (Conv2D)          (None, 1024, 512, 128)    147584
#
#  max_pooling2d_8 (MaxPoolin  (None, 512, 256, 128)     0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 512, 256, 256)     295168
#
#  dropout_19 (Dropout)        (None, 512, 256, 256)     0
#
#  conv2d_41 (Conv2D)          (None, 512, 256, 256)     590080
#
#  max_pooling2d_9 (MaxPoolin  (None, 256, 128, 256)     0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 256, 128, 512)     1180160
#
#  dropout_20 (Dropout)        (None, 256, 128, 512)     0
#
#  conv2d_43 (Conv2D)          (None, 256, 128, 512)     2359808
#
#  max_pooling2d_10 (MaxPooli  (None, 128, 64, 512)      0
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 128, 64, 1024)     4719616
#
#  dropout_21 (Dropout)        (None, 128, 64, 1024)     0
#
#  conv2d_45 (Conv2D)          (None, 128, 64, 1024)     9438208
#
#  max_pooling2d_11 (MaxPooli  (None, 64, 32, 1024)      0
#  ng2D)
#
#  conv2d_46 (Conv2D)          (None, 64, 32, 2048)      18876416
#
#  dropout_22 (Dropout)        (None, 64, 32, 2048)      0
#
#  conv2d_47 (Conv2D)          (None, 64, 32, 2048)      37750784
#
#  conv2d_transpose_8 (Conv2D  (None, 128, 64, 1024)     8389632
#  Transpose)
#
#  conv2d_48 (Conv2D)          (None, 128, 64, 1024)     9438208
#
#  dropout_23 (Dropout)        (None, 128, 64, 1024)     0
#
#  conv2d_49 (Conv2D)          (None, 128, 64, 1024)     9438208
#
#  conv2d_transpose_9 (Conv2D  (None, 256, 128, 512)     2097664
#  Transpose)
#
#  conv2d_50 (Conv2D)          (None, 256, 128, 512)     2359808
#
#  dropout_24 (Dropout)        (None, 256, 128, 512)     0
#
#  conv2d_51 (Conv2D)          (None, 256, 128, 512)     2359808
#
#  conv2d_transpose_10 (Conv2  (None, 512, 256, 256)     524544
#  DTranspose)
#
#  conv2d_52 (Conv2D)          (None, 512, 256, 256)     590080
#
#  dropout_25 (Dropout)        (None, 512, 256, 256)     0
#
#  conv2d_53 (Conv2D)          (None, 512, 256, 256)     590080
#
#  conv2d_transpose_11 (Conv2  (None, 1024, 512, 128)    131200
#  DTranspose)
#
#  conv2d_54 (Conv2D)          (None, 1024, 512, 128)    147584
#
#  dropout_26 (Dropout)        (None, 1024, 512, 128)    0
#
#  conv2d_55 (Conv2D)          (None, 1024, 512, 128)    147584
#
#  conv2d_56 (Conv2D)          (None, 1024, 512, 1)      129
#
# =================================================================
# Total params: 111575937 (425.63 MB)
# Trainable params: 111575937 (425.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Training CNN without skip connections...
# Epoch 1/100
# 381/381 [==============================] - ETA: 0s - loss: 0.0156 - dice_coefficient: 0.0052 - precision_metric: 0.0054 - hausdorff_distance: 5.9147
# Epoch 1: val_loss improved from inf to 0.00921, saving model to 1024_512_CNN.hdf5
# /usr/local/lib/python3.11/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 381/381 [==============================] - 310s 565ms/step - loss: 0.0156 - dice_coefficient: 0.0052 - precision_metric: 0.0054 - hausdorff_distance: 5.9147 - val_loss: 0.0092 - val_dice_coefficient: 0.0112 - val_precision_metric: 0.0060 - val_hausdorff_distance: 0.0000e+00
# Epoch 2/100
# 381/381 [==============================] - ETA: 0s - loss: 0.0036 - dice_coefficient: 0.0077 - precision_metric: 0.0083 - hausdorff_distance: 0.0000e+00
# Epoch 2: val_loss improved from 0.00921 to 0.00709, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 173s 453ms/step - loss: 0.0036 - dice_coefficient: 0.0077 - precision_metric: 0.0083 - hausdorff_distance: 0.0000e+00 - val_loss: 0.0071 - val_dice_coefficient: 0.0132 - val_precision_metric: 0.0073 - val_hausdorff_distance: 0.0000e+00
# Epoch 3/100
# 381/381 [==============================] - ETA: 0s - loss: 0.0034 - dice_coefficient: 0.0128 - precision_metric: 0.0139 - hausdorff_distance: 0.0000e+00
# Epoch 3: val_loss did not improve from 0.00709
# 381/381 [==============================] - 170s 446ms/step - loss: 0.0034 - dice_coefficient: 0.0128 - precision_metric: 0.0139 - hausdorff_distance: 0.0000e+00 - val_loss: 0.0099 - val_dice_coefficient: 0.0184 - val_precision_metric: 0.0098 - val_hausdorff_distance: 0.0000e+00
# Epoch 4/100
# 381/381 [==============================] - ETA: 0s - loss: 0.0023 - dice_coefficient: 0.1381 - precision_metric: 0.1538 - hausdorff_distance: 0.0000e+00
# Epoch 4: val_loss improved from 0.00709 to 0.00206, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 173s 452ms/step - loss: 0.0023 - dice_coefficient: 0.1381 - precision_metric: 0.1538 - hausdorff_distance: 0.0000e+00 - val_loss: 0.0021 - val_dice_coefficient: 0.1734 - val_precision_metric: 0.1198 - val_hausdorff_distance: 0.0000e+00
# Epoch 5/100
# 381/381 [==============================] - ETA: 0s - loss: 0.0013 - dice_coefficient: 0.3663 - precision_metric: 0.3882 - hausdorff_distance: 38.5739
# Epoch 5: val_loss improved from 0.00206 to 0.00203, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 250s 656ms/step - loss: 0.0013 - dice_coefficient: 0.3663 - precision_metric: 0.3882 - hausdorff_distance: 38.5739 - val_loss: 0.0020 - val_dice_coefficient: 0.2415 - val_precision_metric: 0.1563 - val_hausdorff_distance: 56.3628
# Epoch 6/100
# 381/381 [==============================] - ETA: 0s - loss: 9.3530e-04 - dice_coefficient: 0.5459 - precision_metric: 0.5542 - hausdorff_distance: 45.5222
# Epoch 6: val_loss improved from 0.00203 to 0.00079, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 305s 800ms/step - loss: 9.3530e-04 - dice_coefficient: 0.5459 - precision_metric: 0.5542 - hausdorff_distance: 45.5222 - val_loss: 7.9247e-04 - val_dice_coefficient: 0.5099 - val_precision_metric: 0.4679 - val_hausdorff_distance: 38.1889
# Epoch 7/100
# 381/381 [==============================] - ETA: 0s - loss: 7.8418e-04 - dice_coefficient: 0.6050 - precision_metric: 0.6105 - hausdorff_distance: 39.2573
# Epoch 7: val_loss did not improve from 0.00079
# 381/381 [==============================] - 306s 803ms/step - loss: 7.8418e-04 - dice_coefficient: 0.6050 - precision_metric: 0.6105 - hausdorff_distance: 39.2573 - val_loss: 8.9662e-04 - val_dice_coefficient: 0.5237 - val_precision_metric: 0.4226 - val_hausdorff_distance: 53.9189
# Epoch 8/100
# 381/381 [==============================] - ETA: 0s - loss: 6.9176e-04 - dice_coefficient: 0.6428 - precision_metric: 0.6480 - hausdorff_distance: 37.1821
# Epoch 8: val_loss improved from 0.00079 to 0.00067, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 308s 809ms/step - loss: 6.9176e-04 - dice_coefficient: 0.6428 - precision_metric: 0.6480 - hausdorff_distance: 37.1821 - val_loss: 6.6977e-04 - val_dice_coefficient: 0.6093 - val_precision_metric: 0.5414 - val_hausdorff_distance: 54.9144
# Epoch 9/100
# 381/381 [==============================] - ETA: 0s - loss: 6.1871e-04 - dice_coefficient: 0.6788 - precision_metric: 0.6851 - hausdorff_distance: 30.8927
# Epoch 9: val_loss did not improve from 0.00067
# 381/381 [==============================] - 308s 807ms/step - loss: 6.1871e-04 - dice_coefficient: 0.6788 - precision_metric: 0.6851 - hausdorff_distance: 30.8927 - val_loss: 7.4987e-04 - val_dice_coefficient: 0.5846 - val_precision_metric: 0.4889 - val_hausdorff_distance: 63.3128
# Epoch 10/100
# 381/381 [==============================] - ETA: 0s - loss: 5.7268e-04 - dice_coefficient: 0.7018 - precision_metric: 0.7054 - hausdorff_distance: 28.8582
# Epoch 10: val_loss improved from 0.00067 to 0.00054, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 310s 814ms/step - loss: 5.7268e-04 - dice_coefficient: 0.7018 - precision_metric: 0.7054 - hausdorff_distance: 28.8582 - val_loss: 5.4018e-04 - val_dice_coefficient: 0.6764 - val_precision_metric: 0.6316 - val_hausdorff_distance: 24.6369
# Epoch 11/100
# 381/381 [==============================] - ETA: 0s - loss: 5.2694e-04 - dice_coefficient: 0.7223 - precision_metric: 0.7253 - hausdorff_distance: 24.0996
# Epoch 11: val_loss improved from 0.00054 to 0.00047, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 310s 815ms/step - loss: 5.2694e-04 - dice_coefficient: 0.7223 - precision_metric: 0.7253 - hausdorff_distance: 24.0996 - val_loss: 4.7465e-04 - val_dice_coefficient: 0.7074 - val_precision_metric: 0.6957 - val_hausdorff_distance: 23.1214
# Epoch 12/100
# 381/381 [==============================] - ETA: 0s - loss: 5.0381e-04 - dice_coefficient: 0.7350 - precision_metric: 0.7381 - hausdorff_distance: 25.3778
# Epoch 12: val_loss improved from 0.00047 to 0.00045, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 311s 815ms/step - loss: 5.0381e-04 - dice_coefficient: 0.7350 - precision_metric: 0.7381 - hausdorff_distance: 25.3778 - val_loss: 4.4617e-04 - val_dice_coefficient: 0.7244 - val_precision_metric: 0.6984 - val_hausdorff_distance: 21.0103
# Epoch 13/100
# 381/381 [==============================] - ETA: 0s - loss: 4.6316e-04 - dice_coefficient: 0.7550 - precision_metric: 0.7580 - hausdorff_distance: 20.2394
# Epoch 13: val_loss did not improve from 0.00045
# 381/381 [==============================] - 308s 806ms/step - loss: 4.6316e-04 - dice_coefficient: 0.7550 - precision_metric: 0.7580 - hausdorff_distance: 20.2394 - val_loss: 4.5989e-04 - val_dice_coefficient: 0.7176 - val_precision_metric: 0.6828 - val_hausdorff_distance: 24.2677
# Epoch 14/100
# 381/381 [==============================] - ETA: 0s - loss: 4.4306e-04 - dice_coefficient: 0.7658 - precision_metric: 0.7691 - hausdorff_distance: 18.0981
# Epoch 14: val_loss improved from 0.00045 to 0.00042, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 310s 814ms/step - loss: 4.4306e-04 - dice_coefficient: 0.7658 - precision_metric: 0.7691 - hausdorff_distance: 18.0981 - val_loss: 4.1595e-04 - val_dice_coefficient: 0.7459 - val_precision_metric: 0.7252 - val_hausdorff_distance: 19.9840
# Epoch 15/100
# 381/381 [==============================] - ETA: 0s - loss: 4.0822e-04 - dice_coefficient: 0.7842 - precision_metric: 0.7868 - hausdorff_distance: 15.7144
# Epoch 15: val_loss improved from 0.00042 to 0.00040, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 311s 816ms/step - loss: 4.0822e-04 - dice_coefficient: 0.7842 - precision_metric: 0.7868 - hausdorff_distance: 15.7144 - val_loss: 4.0321e-04 - val_dice_coefficient: 0.7734 - val_precision_metric: 0.7348 - val_hausdorff_distance: 22.3530
# Epoch 16/100
# 381/381 [==============================] - ETA: 0s - loss: 4.0062e-04 - dice_coefficient: 0.7882 - precision_metric: 0.7909 - hausdorff_distance: 15.0868
# Epoch 16: val_loss improved from 0.00040 to 0.00038, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 311s 816ms/step - loss: 4.0062e-04 - dice_coefficient: 0.7882 - precision_metric: 0.7909 - hausdorff_distance: 15.0868 - val_loss: 3.7983e-04 - val_dice_coefficient: 0.7843 - val_precision_metric: 0.7548 - val_hausdorff_distance: 18.8424
# Epoch 17/100
# 381/381 [==============================] - ETA: 0s - loss: 3.8624e-04 - dice_coefficient: 0.7958 - precision_metric: 0.7972 - hausdorff_distance: 14.4737
# Epoch 17: val_loss improved from 0.00038 to 0.00037, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 311s 816ms/step - loss: 3.8624e-04 - dice_coefficient: 0.7958 - precision_metric: 0.7972 - hausdorff_distance: 14.4737 - val_loss: 3.6936e-04 - val_dice_coefficient: 0.7899 - val_precision_metric: 0.7456 - val_hausdorff_distance: 16.6174
# Epoch 18/100
# 381/381 [==============================] - ETA: 0s - loss: 3.6395e-04 - dice_coefficient: 0.8075 - precision_metric: 0.8098 - hausdorff_distance: 14.3800
# Epoch 18: val_loss improved from 0.00037 to 0.00036, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 311s 816ms/step - loss: 3.6395e-04 - dice_coefficient: 0.8075 - precision_metric: 0.8098 - hausdorff_distance: 14.3800 - val_loss: 3.6018e-04 - val_dice_coefficient: 0.7994 - val_precision_metric: 0.7585 - val_hausdorff_distance: 16.9014
# Epoch 19/100
# 381/381 [==============================] - ETA: 0s - loss: 3.5191e-04 - dice_coefficient: 0.8136 - precision_metric: 0.8148 - hausdorff_distance: 12.7175
# Epoch 19: val_loss did not improve from 0.00036
# 381/381 [==============================] - 308s 809ms/step - loss: 3.5191e-04 - dice_coefficient: 0.8136 - precision_metric: 0.8148 - hausdorff_distance: 12.7175 - val_loss: 3.7355e-04 - val_dice_coefficient: 0.7892 - val_precision_metric: 0.7469 - val_hausdorff_distance: 19.3026
# Epoch 20/100
# 381/381 [==============================] - ETA: 0s - loss: 4.0561e-04 - dice_coefficient: 0.7880 - precision_metric: 0.7896 - hausdorff_distance: 19.1982
# Epoch 20: val_loss improved from 0.00036 to 0.00035, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 310s 812ms/step - loss: 4.0561e-04 - dice_coefficient: 0.7880 - precision_metric: 0.7896 - hausdorff_distance: 19.1982 - val_loss: 3.5254e-04 - val_dice_coefficient: 0.8066 - val_precision_metric: 0.7743 - val_hausdorff_distance: 16.2116
# Epoch 21/100
# 381/381 [==============================] - ETA: 0s - loss: 3.2619e-04 - dice_coefficient: 0.8280 - precision_metric: 0.8295 - hausdorff_distance: 9.1393
# Epoch 21: val_loss improved from 0.00035 to 0.00032, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 309s 812ms/step - loss: 3.2619e-04 - dice_coefficient: 0.8280 - precision_metric: 0.8295 - hausdorff_distance: 9.1393 - val_loss: 3.2003e-04 - val_dice_coefficient: 0.8203 - val_precision_metric: 0.8006 - val_hausdorff_distance: 13.9447
# Epoch 22/100
# 381/381 [==============================] - ETA: 0s - loss: 3.1709e-04 - dice_coefficient: 0.8325 - precision_metric: 0.8350 - hausdorff_distance: 10.4877
# Epoch 22: val_loss improved from 0.00032 to 0.00030, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 309s 812ms/step - loss: 3.1709e-04 - dice_coefficient: 0.8325 - precision_metric: 0.8350 - hausdorff_distance: 10.4877 - val_loss: 2.9974e-04 - val_dice_coefficient: 0.8306 - val_precision_metric: 0.8114 - val_hausdorff_distance: 15.3015
# Epoch 23/100
# 381/381 [==============================] - ETA: 0s - loss: 3.1487e-04 - dice_coefficient: 0.8333 - precision_metric: 0.8358 - hausdorff_distance: 9.7969
# Epoch 23: val_loss did not improve from 0.00030
# 381/381 [==============================] - 308s 809ms/step - loss: 3.1487e-04 - dice_coefficient: 0.8333 - precision_metric: 0.8358 - hausdorff_distance: 9.7969 - val_loss: 3.1493e-04 - val_dice_coefficient: 0.8261 - val_precision_metric: 0.7883 - val_hausdorff_distance: 13.5138
# Epoch 24/100
# 381/381 [==============================] - ETA: 0s - loss: 3.0907e-04 - dice_coefficient: 0.8372 - precision_metric: 0.8392 - hausdorff_distance: 10.8534
# Epoch 24: val_loss improved from 0.00030 to 0.00029, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 310s 814ms/step - loss: 3.0907e-04 - dice_coefficient: 0.8372 - precision_metric: 0.8392 - hausdorff_distance: 10.8534 - val_loss: 2.9083e-04 - val_dice_coefficient: 0.8407 - val_precision_metric: 0.8193 - val_hausdorff_distance: 14.4547
# Epoch 25/100
# 381/381 [==============================] - ETA: 0s - loss: 2.9954e-04 - dice_coefficient: 0.8421 - precision_metric: 0.8426 - hausdorff_distance: 8.9239
# Epoch 25: val_loss did not improve from 0.00029
# 381/381 [==============================] - 308s 808ms/step - loss: 2.9954e-04 - dice_coefficient: 0.8421 - precision_metric: 0.8426 - hausdorff_distance: 8.9239 - val_loss: 3.2891e-04 - val_dice_coefficient: 0.8202 - val_precision_metric: 0.7769 - val_hausdorff_distance: 14.8511
# Epoch 26/100
# 381/381 [==============================] - ETA: 0s - loss: 3.0408e-04 - dice_coefficient: 0.8404 - precision_metric: 0.8410 - hausdorff_distance: 11.9445
# Epoch 26: val_loss did not improve from 0.00029
# 381/381 [==============================] - 307s 805ms/step - loss: 3.0408e-04 - dice_coefficient: 0.8404 - precision_metric: 0.8410 - hausdorff_distance: 11.9445 - val_loss: 3.0022e-04 - val_dice_coefficient: 0.8336 - val_precision_metric: 0.8177 - val_hausdorff_distance: 16.1468
# Epoch 27/100
# 381/381 [==============================] - ETA: 0s - loss: 2.8134e-04 - dice_coefficient: 0.8521 - precision_metric: 0.8538 - hausdorff_distance: 8.0826
# Epoch 27: val_loss did not improve from 0.00029
# 381/381 [==============================] - 306s 803ms/step - loss: 2.8134e-04 - dice_coefficient: 0.8521 - precision_metric: 0.8538 - hausdorff_distance: 8.0826 - val_loss: 2.9487e-04 - val_dice_coefficient: 0.8357 - val_precision_metric: 0.8084 - val_hausdorff_distance: 13.3009
# Epoch 28/100
# 381/381 [==============================] - ETA: 0s - loss: 2.7744e-04 - dice_coefficient: 0.8531 - precision_metric: 0.8539 - hausdorff_distance: 9.6356
# Epoch 28: val_loss improved from 0.00029 to 0.00027, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 309s 810ms/step - loss: 2.7744e-04 - dice_coefficient: 0.8531 - precision_metric: 0.8539 - hausdorff_distance: 9.6356 - val_loss: 2.7152e-04 - val_dice_coefficient: 0.8490 - val_precision_metric: 0.8428 - val_hausdorff_distance: 14.5217
# Epoch 29/100
# 381/381 [==============================] - ETA: 0s - loss: 2.6100e-04 - dice_coefficient: 0.8622 - precision_metric: 0.8638 - hausdorff_distance: 7.1246
# Epoch 29: val_loss did not improve from 0.00027
# 381/381 [==============================] - 306s 803ms/step - loss: 2.6100e-04 - dice_coefficient: 0.8622 - precision_metric: 0.8638 - hausdorff_distance: 7.1246 - val_loss: 2.8195e-04 - val_dice_coefficient: 0.8470 - val_precision_metric: 0.8111 - val_hausdorff_distance: 13.6883
# Epoch 30/100
# 381/381 [==============================] - ETA: 0s - loss: 2.6062e-04 - dice_coefficient: 0.8627 - precision_metric: 0.8631 - hausdorff_distance: 7.5320
# Epoch 30: val_loss did not improve from 0.00027
# 381/381 [==============================] - 305s 800ms/step - loss: 2.6062e-04 - dice_coefficient: 0.8627 - precision_metric: 0.8631 - hausdorff_distance: 7.5320 - val_loss: 3.0924e-04 - val_dice_coefficient: 0.8278 - val_precision_metric: 0.8344 - val_hausdorff_distance: 16.7875
# Epoch 31/100
# 381/381 [==============================] - ETA: 0s - loss: 2.5524e-04 - dice_coefficient: 0.8647 - precision_metric: 0.8656 - hausdorff_distance: 7.0390
# Epoch 31: val_loss did not improve from 0.00027
# 381/381 [==============================] - 306s 801ms/step - loss: 2.5524e-04 - dice_coefficient: 0.8647 - precision_metric: 0.8656 - hausdorff_distance: 7.0390 - val_loss: 2.7809e-04 - val_dice_coefficient: 0.8495 - val_precision_metric: 0.8410 - val_hausdorff_distance: 13.3774
# Epoch 32/100
# 381/381 [==============================] - ETA: 0s - loss: 2.6297e-04 - dice_coefficient: 0.8612 - precision_metric: 0.8624 - hausdorff_distance: 7.7438
# Epoch 32: val_loss did not improve from 0.00027
# 381/381 [==============================] - 306s 804ms/step - loss: 2.6297e-04 - dice_coefficient: 0.8612 - precision_metric: 0.8624 - hausdorff_distance: 7.7438 - val_loss: 3.0080e-04 - val_dice_coefficient: 0.8353 - val_precision_metric: 0.8253 - val_hausdorff_distance: 17.1722
# Epoch 33/100
# 381/381 [==============================] - ETA: 0s - loss: 2.4399e-04 - dice_coefficient: 0.8710 - precision_metric: 0.8718 - hausdorff_distance: 5.2132
# Epoch 33: val_loss improved from 0.00027 to 0.00027, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 310s 813ms/step - loss: 2.4399e-04 - dice_coefficient: 0.8710 - precision_metric: 0.8718 - hausdorff_distance: 5.2132 - val_loss: 2.6593e-04 - val_dice_coefficient: 0.8562 - val_precision_metric: 0.8274 - val_hausdorff_distance: 12.7737
# Epoch 34/100
# 381/381 [==============================] - ETA: 0s - loss: 2.4184e-04 - dice_coefficient: 0.8721 - precision_metric: 0.8727 - hausdorff_distance: 7.3315
# Epoch 34: val_loss improved from 0.00027 to 0.00025, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 309s 811ms/step - loss: 2.4184e-04 - dice_coefficient: 0.8721 - precision_metric: 0.8727 - hausdorff_distance: 7.3315 - val_loss: 2.5449e-04 - val_dice_coefficient: 0.8596 - val_precision_metric: 0.8696 - val_hausdorff_distance: 12.0723
# Epoch 35/100
# 381/381 [==============================] - ETA: 0s - loss: 2.4046e-04 - dice_coefficient: 0.8734 - precision_metric: 0.8740 - hausdorff_distance: 6.3841
# Epoch 35: val_loss did not improve from 0.00025
# 381/381 [==============================] - 306s 803ms/step - loss: 2.4046e-04 - dice_coefficient: 0.8734 - precision_metric: 0.8740 - hausdorff_distance: 6.3841 - val_loss: 2.6396e-04 - val_dice_coefficient: 0.8617 - val_precision_metric: 0.8478 - val_hausdorff_distance: 9.7889
# Epoch 36/100
# 381/381 [==============================] - ETA: 0s - loss: 2.3603e-04 - dice_coefficient: 0.8759 - precision_metric: 0.8767 - hausdorff_distance: 7.1674
# Epoch 36: val_loss did not improve from 0.00025
# 381/381 [==============================] - 306s 803ms/step - loss: 2.3603e-04 - dice_coefficient: 0.8759 - precision_metric: 0.8767 - hausdorff_distance: 7.1674 - val_loss: 2.6718e-04 - val_dice_coefficient: 0.8546 - val_precision_metric: 0.8486 - val_hausdorff_distance: 12.5465
# Epoch 37/100
# 381/381 [==============================] - ETA: 0s - loss: 2.2508e-04 - dice_coefficient: 0.8813 - precision_metric: 0.8816 - hausdorff_distance: 4.4302
# Epoch 37: val_loss improved from 0.00025 to 0.00025, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 308s 809ms/step - loss: 2.2508e-04 - dice_coefficient: 0.8813 - precision_metric: 0.8816 - hausdorff_distance: 4.4302 - val_loss: 2.5330e-04 - val_dice_coefficient: 0.8543 - val_precision_metric: 0.8492 - val_hausdorff_distance: 12.5535
# Epoch 38/100
# 381/381 [==============================] - ETA: 0s - loss: 2.2424e-04 - dice_coefficient: 0.8815 - precision_metric: 0.8820 - hausdorff_distance: 5.1149
# Epoch 38: val_loss did not improve from 0.00025
# 381/381 [==============================] - 307s 805ms/step - loss: 2.2424e-04 - dice_coefficient: 0.8815 - precision_metric: 0.8820 - hausdorff_distance: 5.1149 - val_loss: 2.8084e-04 - val_dice_coefficient: 0.8529 - val_precision_metric: 0.8495 - val_hausdorff_distance: 12.2561
# Epoch 39/100
# 381/381 [==============================] - ETA: 0s - loss: 2.2334e-04 - dice_coefficient: 0.8822 - precision_metric: 0.8828 - hausdorff_distance: 6.2225
# Epoch 39: val_loss did not improve from 0.00025
# 381/381 [==============================] - 307s 804ms/step - loss: 2.2334e-04 - dice_coefficient: 0.8822 - precision_metric: 0.8828 - hausdorff_distance: 6.2225 - val_loss: 2.5818e-04 - val_dice_coefficient: 0.8670 - val_precision_metric: 0.8352 - val_hausdorff_distance: 9.7694
# Epoch 40/100
# 381/381 [==============================] - ETA: 0s - loss: 2.2039e-04 - dice_coefficient: 0.8836 - precision_metric: 0.8838 - hausdorff_distance: 4.4002
# Epoch 40: val_loss improved from 0.00025 to 0.00024, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 308s 809ms/step - loss: 2.2039e-04 - dice_coefficient: 0.8836 - precision_metric: 0.8838 - hausdorff_distance: 4.4002 - val_loss: 2.4056e-04 - val_dice_coefficient: 0.8701 - val_precision_metric: 0.8617 - val_hausdorff_distance: 9.7721
# Epoch 41/100
# 381/381 [==============================] - ETA: 0s - loss: 2.0920e-04 - dice_coefficient: 0.8897 - precision_metric: 0.8902 - hausdorff_distance: 6.0149
# Epoch 41: val_loss did not improve from 0.00024
# 381/381 [==============================] - 306s 804ms/step - loss: 2.0920e-04 - dice_coefficient: 0.8897 - precision_metric: 0.8902 - hausdorff_distance: 6.0149 - val_loss: 2.6321e-04 - val_dice_coefficient: 0.8629 - val_precision_metric: 0.8734 - val_hausdorff_distance: 13.6285
# Epoch 42/100
# 381/381 [==============================] - ETA: 0s - loss: 2.0804e-04 - dice_coefficient: 0.8901 - precision_metric: 0.8902 - hausdorff_distance: 5.8057
# Epoch 42: val_loss did not improve from 0.00024
# 381/381 [==============================] - 307s 806ms/step - loss: 2.0804e-04 - dice_coefficient: 0.8901 - precision_metric: 0.8902 - hausdorff_distance: 5.8057 - val_loss: 2.5079e-04 - val_dice_coefficient: 0.8693 - val_precision_metric: 0.8445 - val_hausdorff_distance: 11.4882
# Epoch 43/100
# 381/381 [==============================] - ETA: 0s - loss: 2.0761e-04 - dice_coefficient: 0.8907 - precision_metric: 0.8904 - hausdorff_distance: 4.3817
# Epoch 43: val_loss did not improve from 0.00024
# 381/381 [==============================] - 306s 803ms/step - loss: 2.0761e-04 - dice_coefficient: 0.8907 - precision_metric: 0.8904 - hausdorff_distance: 4.3817 - val_loss: 2.5169e-04 - val_dice_coefficient: 0.8730 - val_precision_metric: 0.8533 - val_hausdorff_distance: 13.3781
# Epoch 44/100
# 381/381 [==============================] - ETA: 0s - loss: 1.9803e-04 - dice_coefficient: 0.8958 - precision_metric: 0.8964 - hausdorff_distance: 4.0861
# Epoch 44: val_loss improved from 0.00024 to 0.00024, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 308s 808ms/step - loss: 1.9803e-04 - dice_coefficient: 0.8958 - precision_metric: 0.8964 - hausdorff_distance: 4.0861 - val_loss: 2.3988e-04 - val_dice_coefficient: 0.8757 - val_precision_metric: 0.8710 - val_hausdorff_distance: 11.5713
# Epoch 45/100
# 381/381 [==============================] - ETA: 0s - loss: 1.9688e-04 - dice_coefficient: 0.8960 - precision_metric: 0.8967 - hausdorff_distance: 4.7533
# Epoch 45: val_loss improved from 0.00024 to 0.00024, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 311s 810ms/step - loss: 1.9688e-04 - dice_coefficient: 0.8960 - precision_metric: 0.8967 - hausdorff_distance: 4.7533 - val_loss: 2.3631e-04 - val_dice_coefficient: 0.8736 - val_precision_metric: 0.8810 - val_hausdorff_distance: 11.8016
# Epoch 46/100
# 381/381 [==============================] - ETA: 0s - loss: 1.9675e-04 - dice_coefficient: 0.8962 - precision_metric: 0.8965 - hausdorff_distance: 6.1788
# Epoch 46: val_loss did not improve from 0.00024
# 381/381 [==============================] - 306s 802ms/step - loss: 1.9675e-04 - dice_coefficient: 0.8962 - precision_metric: 0.8965 - hausdorff_distance: 6.1788 - val_loss: 2.4162e-04 - val_dice_coefficient: 0.8756 - val_precision_metric: 0.8790 - val_hausdorff_distance: 12.6799
# Epoch 47/100
# 381/381 [==============================] - ETA: 0s - loss: 1.9466e-04 - dice_coefficient: 0.8972 - precision_metric: 0.8978 - hausdorff_distance: 4.6020
# Epoch 47: val_loss did not improve from 0.00024
# 381/381 [==============================] - 305s 801ms/step - loss: 1.9466e-04 - dice_coefficient: 0.8972 - precision_metric: 0.8978 - hausdorff_distance: 4.6020 - val_loss: 2.3816e-04 - val_dice_coefficient: 0.8740 - val_precision_metric: 0.8694 - val_hausdorff_distance: 11.6116
# Epoch 48/100
# 381/381 [==============================] - ETA: 0s - loss: 1.8873e-04 - dice_coefficient: 0.9003 - precision_metric: 0.9009 - hausdorff_distance: 3.4909
# Epoch 48: val_loss did not improve from 0.00024
# 381/381 [==============================] - 306s 802ms/step - loss: 1.8873e-04 - dice_coefficient: 0.9003 - precision_metric: 0.9009 - hausdorff_distance: 3.4909 - val_loss: 2.4502e-04 - val_dice_coefficient: 0.8817 - val_precision_metric: 0.8604 - val_hausdorff_distance: 15.0597
# Epoch 49/100
# 381/381 [==============================] - ETA: 0s - loss: 1.9180e-04 - dice_coefficient: 0.8992 - precision_metric: 0.8996 - hausdorff_distance: 4.8187
# Epoch 49: val_loss did not improve from 0.00024
# 381/381 [==============================] - 305s 801ms/step - loss: 1.9180e-04 - dice_coefficient: 0.8992 - precision_metric: 0.8996 - hausdorff_distance: 4.8187 - val_loss: 2.3716e-04 - val_dice_coefficient: 0.8840 - val_precision_metric: 0.8849 - val_hausdorff_distance: 15.3772
# Epoch 50/100
# 381/381 [==============================] - ETA: 0s - loss: 1.8357e-04 - dice_coefficient: 0.9037 - precision_metric: 0.9037 - hausdorff_distance: 3.5228
# Epoch 50: val_loss improved from 0.00024 to 0.00024, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 308s 809ms/step - loss: 1.8357e-04 - dice_coefficient: 0.9037 - precision_metric: 0.9037 - hausdorff_distance: 3.5228 - val_loss: 2.3532e-04 - val_dice_coefficient: 0.8859 - val_precision_metric: 0.8740 - val_hausdorff_distance: 12.3305
# Epoch 51/100
# 381/381 [==============================] - ETA: 0s - loss: 1.8916e-04 - dice_coefficient: 0.9008 - precision_metric: 0.9014 - hausdorff_distance: 3.9006
# Epoch 51: val_loss did not improve from 0.00024
# 381/381 [==============================] - 305s 802ms/step - loss: 1.8916e-04 - dice_coefficient: 0.9008 - precision_metric: 0.9014 - hausdorff_distance: 3.9006 - val_loss: 2.4161e-04 - val_dice_coefficient: 0.8845 - val_precision_metric: 0.8740 - val_hausdorff_distance: 11.2655
# Epoch 52/100
# 381/381 [==============================] - ETA: 0s - loss: 1.8512e-04 - dice_coefficient: 0.9027 - precision_metric: 0.9031 - hausdorff_distance: 3.8130
# Epoch 52: val_loss did not improve from 0.00024
# 381/381 [==============================] - 305s 800ms/step - loss: 1.8512e-04 - dice_coefficient: 0.9027 - precision_metric: 0.9031 - hausdorff_distance: 3.8130 - val_loss: 2.3842e-04 - val_dice_coefficient: 0.8752 - val_precision_metric: 0.8934 - val_hausdorff_distance: 9.4431
# Epoch 53/100
# 381/381 [==============================] - ETA: 0s - loss: 1.8007e-04 - dice_coefficient: 0.9046 - precision_metric: 0.9053 - hausdorff_distance: 2.9443
# Epoch 53: val_loss improved from 0.00024 to 0.00023, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 308s 810ms/step - loss: 1.8007e-04 - dice_coefficient: 0.9046 - precision_metric: 0.9053 - hausdorff_distance: 2.9443 - val_loss: 2.3161e-04 - val_dice_coefficient: 0.8865 - val_precision_metric: 0.8869 - val_hausdorff_distance: 11.4078
# Epoch 54/100
# 381/381 [==============================] - ETA: 0s - loss: 1.7365e-04 - dice_coefficient: 0.9088 - precision_metric: 0.9089 - hausdorff_distance: 4.9602
# Epoch 54: val_loss improved from 0.00023 to 0.00023, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 309s 811ms/step - loss: 1.7365e-04 - dice_coefficient: 0.9088 - precision_metric: 0.9089 - hausdorff_distance: 4.9602 - val_loss: 2.2758e-04 - val_dice_coefficient: 0.8849 - val_precision_metric: 0.8893 - val_hausdorff_distance: 11.0371
# Epoch 55/100
# 381/381 [==============================] - ETA: 0s - loss: 1.7671e-04 - dice_coefficient: 0.9071 - precision_metric: 0.9076 - hausdorff_distance: 3.9335
# Epoch 55: val_loss improved from 0.00023 to 0.00022, saving model to 1024_512_CNN.hdf5
# 381/381 [==============================] - 308s 810ms/step - loss: 1.7671e-04 - dice_coefficient: 0.9071 - precision_metric: 0.9076 - hausdorff_distance: 3.9335 - val_loss: 2.2069e-04 - val_dice_coefficient: 0.8873 - val_precision_metric: 0.8898 - val_hausdorff_distance: 9.2246
# Epoch 56/100
# 381/381 [==============================] - ETA: 0s - loss: 1.7119e-04 - dice_coefficient: 0.9099 - precision_metric: 0.9102 - hausdorff_distance: 4.1846
# Epoch 56: val_loss did not improve from 0.00022
# 381/381 [==============================] - 305s 801ms/step - loss: 1.7119e-04 - dice_coefficient: 0.9099 - precision_metric: 0.9102 - hausdorff_distance: 4.1846 - val_loss: 2.3614e-04 - val_dice_coefficient: 0.8861 - val_precision_metric: 0.8838 - val_hausdorff_distance: 13.2689
# Epoch 57/100
# 381/381 [==============================] - ETA: 0s - loss: 1.7083e-04 - dice_coefficient: 0.9099 - precision_metric: 0.9105 - hausdorff_distance: 3.4338
# Epoch 57: val_loss did not improve from 0.00022
# 381/381 [==============================] - 305s 801ms/step - loss: 1.7083e-04 - dice_coefficient: 0.9099 - precision_metric: 0.9105 - hausdorff_distance: 3.4338 - val_loss: 2.4895e-04 - val_dice_coefficient: 0.8887 - val_precision_metric: 0.8635 - val_hausdorff_distance: 8.9169
# Epoch 58/100
# 381/381 [==============================] - ETA: 0s - loss: 1.6901e-04 - dice_coefficient: 0.9085 - precision_metric: 0.9084 - hausdorff_distance: 3.6120
# Epoch 58: val_loss did not improve from 0.00022
# 381/381 [==============================] - 305s 801ms/step - loss: 1.6901e-04 - dice_coefficient: 0.9085 - precision_metric: 0.9084 - hausdorff_distance: 3.6120 - val_loss: 2.3373e-04 - val_dice_coefficient: 0.8891 - val_precision_metric: 0.8864 - val_hausdorff_distance: 9.4732
# Epoch 59/100
# 381/381 [==============================] - ETA: 0s - loss: 1.6510e-04 - dice_coefficient: 0.9136 - precision_metric: 0.9136 - hausdorff_distance: 3.6128
# Epoch 59: val_loss did not improve from 0.00022
# 381/381 [==============================] - 305s 800ms/step - loss: 1.6510e-04 - dice_coefficient: 0.9136 - precision_metric: 0.9136 - hausdorff_distance: 3.6128 - val_loss: 2.5847e-04 - val_dice_coefficient: 0.8831 - val_precision_metric: 0.8714 - val_hausdorff_distance: 10.1505
# Epoch 60/100
# 381/381 [==============================] - ETA: 0s - loss: 1.6287e-04 - dice_coefficient: 0.9140 - precision_metric: 0.9143 - hausdorff_distance: 3.8321
# Epoch 60: val_loss did not improve from 0.00022
# 381/381 [==============================] - 305s 801ms/step - loss: 1.6287e-04 - dice_coefficient: 0.9140 - precision_metric: 0.9143 - hausdorff_distance: 3.8321 - val_loss: 2.4531e-04 - val_dice_coefficient: 0.8818 - val_precision_metric: 0.9045 - val_hausdorff_distance: 8.6402
# Epoch 61/100
# 381/381 [==============================] - ETA: 0s - loss: 1.6235e-04 - dice_coefficient: 0.9147 - precision_metric: 0.9151 - hausdorff_distance: 2.5803
# Epoch 61: val_loss did not improve from 0.00022
# 381/381 [==============================] - 306s 802ms/step - loss: 1.6235e-04 - dice_coefficient: 0.9147 - precision_metric: 0.9151 - hausdorff_distance: 2.5803 - val_loss: 2.4145e-04 - val_dice_coefficient: 0.8932 - val_precision_metric: 0.8877 - val_hausdorff_distance: 9.8463
# Epoch 62/100
# 381/381 [==============================] - ETA: 0s - loss: 1.6253e-04 - dice_coefficient: 0.9148 - precision_metric: 0.9155 - hausdorff_distance: 3.7104
# Epoch 62: val_loss did not improve from 0.00022
# 381/381 [==============================] - 307s 805ms/step - loss: 1.6253e-04 - dice_coefficient: 0.9148 - precision_metric: 0.9155 - hausdorff_distance: 3.7104 - val_loss: 3.0098e-04 - val_dice_coefficient: 0.8557 - val_precision_metric: 0.8161 - val_hausdorff_distance: 38.0189
# Epoch 63/100
# 381/381 [==============================] - ETA: 0s - loss: 1.5941e-04 - dice_coefficient: 0.9161 - precision_metric: 0.9163 - hausdorff_distance: 4.1440
# Epoch 63: val_loss did not improve from 0.00022
# 381/381 [==============================] - 306s 802ms/step - loss: 1.5941e-04 - dice_coefficient: 0.9161 - precision_metric: 0.9163 - hausdorff_distance: 4.1440 - val_loss: 2.3238e-04 - val_dice_coefficient: 0.8889 - val_precision_metric: 0.8924 - val_hausdorff_distance: 9.4337
# Epoch 64/100
# 381/381 [==============================] - ETA: 0s - loss: 1.5423e-04 - dice_coefficient: 0.9191 - precision_metric: 0.9194 - hausdorff_distance: 2.5886
# Epoch 64: val_loss did not improve from 0.00022
# 381/381 [==============================] - 305s 800ms/step - loss: 1.5423e-04 - dice_coefficient: 0.9191 - precision_metric: 0.9194 - hausdorff_distance: 2.5886 - val_loss: 2.3951e-04 - val_dice_coefficient: 0.8928 - val_precision_metric: 0.9025 - val_hausdorff_distance: 8.8261
# Epoch 65/100
# 381/381 [==============================] - ETA: 0s - loss: 1.5340e-04 - dice_coefficient: 0.9195 - precision_metric: 0.9200 - hausdorff_distance: 2.5253
# Epoch 65: val_loss did not improve from 0.00022
# 381/381 [==============================] - 306s 802ms/step - loss: 1.5340e-04 - dice_coefficient: 0.9195 - precision_metric: 0.9200 - hausdorff_distance: 2.5253 - val_loss: 2.3242e-04 - val_dice_coefficient: 0.8936 - val_precision_metric: 0.8935 - val_hausdorff_distance: 11.5958
#
# Training completed. Model weights saved.
